# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic8\\01.jpg")
height,width=image.shape[:2]
t=np.float32([[0.5,0,0],[0,0.5,0]])
image_resized=cv2.warpAffine(image,t,(width//2,height//2))
plt.figure(figsize=[12,7])
plt.subplot(121);plt.imshow(image[...,::-1]);plt.title("image");
plt.subplot(122);plt.imshow(image_resized[...,::-1]);plt.title("image_resized");
plt.show()

# %%
rotation_mount_degree=10
theta=rotation_mount_degree*np.pi/180
image=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic8\\01.jpg")
height,width=image.shape[:2]
t1=np.float32([[np.cos(theta),-np.sin(theta)],[np.sin(theta),np.cos(theta)]])
t2=np.float32([[0.5,0],[0,0.5]])
t=np.matmul(t1,t2)
final_t=np.zeros((2,3))
final_t[:,:-1]=t
print(final_t)
# Out:
# [[ 0.49240386 -0.08682409  0.        ]
#  [ 0.08682409  0.49240386  0.        ]]

# %%
result=cv2.warpAffine(image,final_t,(width,height))
plt.figure(figsize=[12,7])
plt.subplot(121);plt.imshow(image[...,::-1]);plt.title("image");
plt.subplot(122);plt.imshow(result[...,::-1]);plt.title("image_resized");
plt.show()

# %%
image=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic8\\03.jpeg")
cv2.imshow("orginal",image)
cv2.waitKey()
image_scale=cv2.resize(image,None,fx=0.75,fx=0.75)
cv2.imshow("scale",image_scale)
cv2.waitKey()
image_scale=cv2.resize(image,None,fx=2,fx=2,interpolation=cv2.INTER_CUBIC)
cv2.imshow("interplation_cubic",image_scale)
cv2.waitKey()
image_scale=cv2.resize(image,(900,400),interpolation=cv2.INTER_AREA)
cv2.imshow("Skew",image_scale)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
#   Cell In[5], line 4
#     image_scale=cv2.resize(image,None,fx=0.75,fx=0.75)
#                                               ^
# SyntaxError: keyword argument repeated: fx
